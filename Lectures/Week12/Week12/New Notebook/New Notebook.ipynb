# %%
import os
import arcpy
import pandas as pd
from arcgis.gis import GIS,User
from arcgis.mapping import WebMap
from IPython.display import display
from datetime import datetime, timedelta
from arcgis.features import FeatureLayerCollection
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 from arcgis.gis import GIS,User
# ----> 5 from arcgis.mapping import WebMap
#       6 from IPython.display import display
#       7 from datetime import datetime, timedelta
#
# ImportError: cannot import name 'WebMap' from 'arcgis.mapping' (D:\ArcGISPro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\mapping\__init__.py)

# %%
PORTAL = my
