# %%
import os
import arcpy
import pandas as pd
from arcgis.gis import GIS, User
from IPython.display import display
from datetime import datetime, timedelta
from arcgis.features import FeatureLayerCollection

# %%
portal = 'https://uca-gis.maps.arcgis.com/'
my_gis = GIS("pro")

# %%
print(my_gis.properties.user)
# Out:
# {
#   "username": "YWU_UCA_GIS",
#   "udn": null,
#   "id": "b606e273809642bb994f8493f3eae8b7",
#   "fullName": "Yanan Wu",
#   "availableCredits": 943.5598,
#   "assignedCredits": 1000.0,
#   "categories": [],
#   "emailStatus": "notverified",
#   "firstName": "Yanan",
#   "lastName": "Wu",
#   "preferredView": null,
#   "description": null,
#   "email": "YWU@UCA.EDU",
#   "userType": "both",
#   "idpUsername": "YWU",
#   "favGroupId": "24b1def15642454da2d32084f98d1c39",
#   "lastLogin": 1762902074000,
#   "mfaEnabled": false,
#   "mfaEnforcementExempt": false,
#   "validateUserProfile": true,
#   "storageUsage": 123851983684,
#   "storageQuota": 2199023255552,
#   "orgId": "FrMXGnrs7J0gRe2w",
#   "role": "org_publisher",
#   "privileges": [
#     "features:user:edit",
#     "portal:publisher:createDataPipelines",
#     "portal:publisher:publishDynamicImagery",
#     "portal:publisher:publishFeatures",
#     "portal:publisher:publishScenes",
# ...

# %%
print(my_gis.properties.user.username)
# Out:
# YWU_UCA_GIS

# %%
os.getcwd()
# Out:
# 'E:\\ConwayTeaching\\Field_Techniques\\Field_Techniques\\docs\\Labs\\Lab08\\Lab08'

# %%
shapefile_path = os.path.join(os.getcwd(), 'Data', 'dallas_311.zip')
print("Full path:", shapefile_path)
print("Exists?", os.path.exists(shapefile_path))
# Out:
# Full path: E:\ConwayTeaching\Field_Techniques\Field_Techniques\docs\Labs\Lab08\Lab08\Data\dallas_311.zip
# Exists? True

# %%
# shapefile_path = r"E:\ConwayTeaching\Field_Techniques\Field_Techniques\docs\Lectures\Week13\Week13\Data\inct_dallas.zip"

folder_name = "Dallas 311 Service"

if folder_name not in [f["title"] for f in my_gis.users.me.folders]:
    my_gis.content.folders.create(folder_name)
    
item_properties = {
    'title': 'Dallas 311 Service',
    'type': 'Shapefile',
    'tags': 'Dallas, 311, Service'
}
        
added_item = my_gis.content.add(item_properties, data = shapefile_path,folder='Dallas 311 Service')
# Out:
# D:\ArcGISPro\bin\Python\envs\arcgispro-py3\Lib\site-packages\IPython\core\interactiveshell.py:3550: DeprecatedWarning: add is deprecated as of 2.3.0 and has been removed in 3.0.0. Use `Folder.add()` instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
published_item = added_item.publish()
